# %% [markdown]
# <a href="https://colab.research.google.com/github/manikanta-eng/python-training/blob/main/training_day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
num=list(map(int,input().split()))
di={}
for i in num:
  if i in di:
    di[i]+=1
  else:
    di[i]=1
print(di)
lis=list(di.values())
print(lis)
mx=max(lis)
print(mx)
if lis.count(mx)>1:
  print(-1)
else:
  print(mx(di,key=di.get))

# %% [markdown]
# **special string**

# %%
ch = input("Enter a character: ")
print("ASCII value of", ch, "is", ord(ch))

# %%
a=input()
s=input()
total=0
for i in a:
  if i not in s:
    temp=125
    for j in s:
      d=abs(ord(i)-ord(j))
      temp=min(temp,d,26-d)
    total+=temp
print(total)

# %%
vertex
edge
adjacent

# %%
def add_nodes(v):
  if v in graph:
    print(v,"is already present in graph")
  else:
    graph[v]=[]
def add_edge(v1,v2,cost):
  if v1 not in graph:
    print(v1,"is not present in graph")
    elif v2 not in graph:
    print(v2,"is not present in graph")
  else:
    graph[v1].append((v2,cost))
    graph[v2].append((v1,cost))
graph={}
add_nodes("A")
add_nodes("B")
add_edges('A','B')
print(graph)
def delete_node(v):
  if v not in graph:
    print(v,"not present in graph")
  else:
    graph.pop(v)
    for i in graph:
      list1=graph[i]
      if v in list1:
        list1.remove(v)

# %%
def add_nodes(v):
    if v in graph:
        print(v,"already present")
    else:
        graph[v]=[]
def add_edges(v1,v2):
    if v1 not in graph:
        print(v1,"Not present")
    elif v2 not in graph:
        print(v1,"Not present")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
def delete_edge(v1,v2):
    if v1 not in graph:
        print(v1,"Not present")
    elif v2 not in graph:
        print(v2,"Not present")
    else:
        if v2 in graph[v1]:
            graph[v1].remove(v2)
            graph[v2].remove(v1)





def delete_node(v):
    if v not in graph:
        print(v,"not present in graph")
    else:
        graph.pop(v)
        for i in graph:
            list1=graph[i]
            if v in list1:
                list1.remove(v)
graph={}
add_nodes("A")
add_nodes("B")
add_edges('A','B')
delete_edge('A','B')
#delete_node('A')
print(graph)
