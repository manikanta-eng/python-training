# %% [markdown]
# <a href="https://colab.research.google.com/github/manikanta-eng/python-training/blob/main/7_4_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class Queue:
    def __init__(self):
        self.front = None
        self.rear = None

    def enqueue(self, data):
        new_node = Node(data)
        if self.rear is None:  # Queue is empty
            self.front = new_node
            self.rear = new_node
        else:  # Add to the rear
            self.rear.next = new_node
            self.rear = new_node

    def dequeue(self):
        if self.front is None:  # Queue is empty
            print("Queue is empty, cannot dequeue.")
            return None

        temp = self.front
        self.front = temp.next
        if self.front is None:  # If queue becomes empty after dequeue
            self.rear = None
        return temp.data

    def display(self):
        if self.front is None:
            print("Queue is empty.")
            return

        current = self.front
        while current:
            print(current.data, end=" ")
            current = current.next
        print() # Print a new line after displaying elements

    def is_empty(self):
        return self.front is None

    def peek(self):
        if self.is_empty():
            print("Queue is empty, can not return anything.")
            return None
        else:
            return self.front.data

# Example usage
q = Queue()
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
q.display()

print(f"Peek: {q.peek()}")

q.dequeue()
q.display()

print(f"Is empty: {q.is_empty()}")

q.dequeue()
q.dequeue()

q.display()
print(f"Is empty: {q.is_empty()}")
print(f"Peek: {q.peek()}")
q.dequeue()
# Out:
# 1 2 3
# Peek: 1
# 2 3
# Is empty: False
# Queue is empty.
# Is empty: True
# Queue is empty, can not return anything.
# Peek: None
# Queue is empty, cannot dequeue.

# %% [markdown]
# **Trees**

# %% [markdown]
# types of trees:
#
# 1)binary tree
#
# 2)full binary tree
#
# 3)complete binary tree
#
# 4)almost complete binary tree
#
# **1)binary tree**:
#
# 0,1,2 nodes
#
# **2)FULL BINARY**
#
# 0,2
#
# **3)complete binary tree**
#
# 1) after completion of upper level only come to the low level
#
# 2)after completion of left side,than only come to right side

# %% [markdown]
# **preorder**
#
# first print ,then left , then right

# %%
def preorder(node):
  if node:
    print(node.data, end=" ")
    preorder(node.left)
    preorder(node.right)

# %% [markdown]
# **inorder**
#
# first left,next print and then right

# %%
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=" ")
    inorder(node.right)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Example Tree
#       1
#      / \
#     2   3
#    / \
#   4   5
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

print("Preorder traversal:", end=" ")
preorder(root)
print("\nInorder traversal:", end=" ")
inorder(root)
# Out:
# Preorder traversal: 1 2 4 5 3
# Inorder traversal: 4 2 5 1 3

# %%
def postorder(node):
  if node:
    postorder(node.left)
    postorder(node.right)
    print(node.data, end=" ")

print("Postorder traversal:", end=" ")
postorder(root)
print()
# Out:
# Postorder traversal: 4 5 2 3 1

# %% [markdown]
# **post order**
#
# first left and right then print

# %% [markdown]
# **travarsal algorithms**
#
# 1) Inorder:   ----> unique tree
#
# preorder
#
# 2)inorder:     ----> unique tree
#
# preorder
#
# 3)postorder:   1 2 3
#
# **(2n)!**
#
# **---------**
#
# **(n+1)!n!**

# %%
inorder : ABCDEFG
postorder:ACBEGFD

        D
      /   \
     B     F
    / \   / \
   A   C E   G

# %%
inorder : ACBEDGF

postorder:CAEBGFD

         D
        / \
       B   F
      / \ /
     A  E G
      \
       C

# %%
pre order: 1 2 3
